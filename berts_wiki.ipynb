# %%
# A dependency of the preprocessing for BERT inputs
# !pip install -q -U "tensorflow-text==2.8.*
# !pip install -q tf-models-official==2.7.0

import os
import shutil

import tensorflow as tf
import tensorflow_hub as hub
import tensorflow_text as text
from official.nlp import optimization  # to create AdamW optimizer

import matplotlib.pyplot as plt

tf.get_logger().setLevel('ERROR')
# Out:
# /bin/bash: -c: line 0: unexpected EOF while looking for matching `"'
# /bin/bash: -c: line 1: syntax error: unexpected end of file

# %%
url = 'https://storage.googleapis.com/jigsaw-unintended-bias-in-toxicity-classification/wikipedia_toxicity_subtypes_v0.3.zip'


dataset = tf.keras.utils.get_file('wikipedia_toxicity_subtypes_v0.3.zip', url,
                                  untar=True, cache_dir='.',
                                  cache_subdir='')
# Out:
# ...
# 53035008/53025584 [==============================] - 0s 0us/step

# %%
# !unzip /content/wikipedia_toxicity_subtypes_v0.3.zip.tar.gz
# Out:
# Archive:  /content/wikipedia_toxicity_subtypes_v0.3.zip.tar.gz
#   inflating: wikidata_train.csv
#   inflating: wikidata_test.csv
#   inflating: __MACOSX/._wikidata_test.csv
#   inflating: wikidata_multilingual_validation.csv
#   inflating: __MACOSX/._wikidata_multilingual_validation.csv
#   inflating: wikidata_multilingual_test.csv
#   inflating: __MACOSX/._wikidata_multilingual_test.csv

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('wikidata_train.csv')

arr = df.to_numpy()
ds = arr[:, 1:8]
text = ds[:, :1]
label = ds[:, 1:]
label1 = np.sum(label, axis=1)
target = np.where(label1 >= 1, 1, 0)
text = text.reshape(159571,)
n = np.stack((text,target))

# %%
df.head()
# Out:
#                  id                                       comment_text  toxic  \
# 0  0000997932d777bf  Explanation\nWhy the edits made under my usern...      0
# 1  000103f0d9cfb60f  D'aww! He matches this background colour I'm s...      0
# 2  000113f07ec002fd  Hey man, I'm really not trying to edit war. It...      0
# 3  0001b41b1c6bb37e  "\nMore\nI can't make any real suggestions on ...      0
# 4  0001d958c54c6e35  You, sir, are my hero. Any chance you remember...      0
#
#    severe_toxic  obscene  threat  insult  identity_hate lang
# 0             0        0       0       0              0   en
# 1             0        0       0       0              0   en
# 2             0        0       0       0              0   en
# 3             0        0       0       0              0   en
# 4             0        0       0       0              0   en

# %%
dt = pd.read_csv('wikidata_test.csv')
arrtest = dt.to_numpy()
dm = arrtest[:, 1:8]
text1 = dm[:, :1]
l = dm[:, 1:]
l1 = np.sum(l, axis=1)
target1 = np.where(l1>=1, 1, 0)
print(len(text1))
print(target1.shape)
text1 = text1.reshape(63978,)
n1 = np.stack((text1,target1))
# Out:
# 63978
# (63978,)

# %%
# !pip install tensorflow
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !pip install git+https://github.com/huggingface/transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Cloning https://github.com/huggingface/transformers to /tmp/pip-req-build-nlpm41py
#   Running command git clone -q https://github.com/huggingface/transformers /tmp/pip-req-build-nlpm41py
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# ...
#      |████████████████████████████████| 101 kB 4.9 MB/s
# ...
#      |████████████████████████████████| 6.6 MB 43.8 MB/s
# ...
#   Created wheel for transformers: filename=transformers-4.22.0.dev0-py3-none-any.whl size=4698078 sha256=7a462a533645dbb0bae4a5da2adbe9c8c878de117c041204b1918940522f1f6e
#   Stored in directory: /tmp/pip-ephem-wheel-cache-vupbsjm9/wheels/35/2e/a7/d819e3310040329f0f47e57c9e3e7a7338aa5e74c49acfe522
# Successfully built transformers
# ...

# %%
from transformers import DataCollatorWithPadding
# Out:
# The cache for model files in Transformers v4.22.0 has been updated. Migrating your old cache. This is a one-time only operation. You can interrupt this and resume the migration later on by calling `transformers.utils.move_cache()`.
# Moving 0 files to the new cache system
# 0it [00:00, ?it/s]

# %%
nT = n.T
from transformers import AutoTokenizer

tokenizer = AutoTokenizer.from_pretrained("distilbert-base-uncased")
def preprocess_function(examples):
    return tokenizer(examples["text"], truncation=True)
# Out:
# Downloading:   0%|          | 0.00/28.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/483 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/466k [00:00<?, ?B/s]

# %%
from huggingface_hub import notebook_login
notebook_login()

# %%
# !apt install git-lfs
# !git config --global user.email jli0211@bu.edu
# !git config --global user.name Jacqueline
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# git-lfs is already the newest version (2.3.4-1).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 19 not upgraded.

# %%
import transformers
print(transformers.__version__)
# Out:
# 4.22.0.dev0

# %%
# !pip install datasets
from datasets import load_dataset
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 365 kB 6.3 MB/s
# ...
#      |████████████████████████████████| 141 kB 35.4 MB/s
# ...
#      |████████████████████████████████| 212 kB 18.4 MB/s
# ...
#      |████████████████████████████████| 115 kB 41.2 MB/s
# ...
#      |████████████████████████████████| 127 kB 22.6 MB/s
# ...
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
# ...
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-30-297c7a8f8225> in <module>()
#       1 get_ipython().system('pip install datasets')
#       2 from datasets import load_dataset
# ----> 3 from evaluate import load
#
# ModuleNotFoundError: No module named 'evaluate'
#
# ...

# %%
from huggingface_hub import notebook_login

notebook_login()
# Out:
# Login successful
# Your token has been saved to /root/.huggingface/token
# Authenticated through git-credential store but this isn't the helper defined on your machine.
# You might have to re-authenticate when pushing to the Hugging Face Hub. Run the following command in your terminal in case you want to set this credential helper as the default
#
# git config --global credential.helper store

# %%
from transformers import DataCollatorWithPadding

# %%
data_collator = ata_collator = DataCollatorWithPadding(tokenizer=tokenizer, return_tensors="tf")

# %%
from datasets import load_dataset
n = pd.DataFrame(nT)
n.columns = ['text', 'label']
n.head()
# Out:
#                                                 text label
# 0  Explanation\nWhy the edits made under my usern...     0
# 1  D'aww! He matches this background colour I'm s...     0
# 2  Hey man, I'm really not trying to edit war. It...     0
# 3  "\nMore\nI can't make any real suggestions on ...     0
# 4  You, sir, are my hero. Any chance you remember...     0

# %%
q = n.to_csv(r'C:\Users\Jacqueline Li\Desktop\New folder\processed_data.csv', index = False, header = True)

# %%
test_transposed = pd.DataFrame(n1.T)
test_transposed.columns = ['text', 'label']
q1 = test_transposed.to_csv(r'C:\Users\Jacqueline Li\Desktop\New folder\test_data.csv', index = False, header=True)

# %%
data = load_dataset('csv', data_files=r'C:\Users\Jacqueline Li\Desktop\New folder\processed_data.csv')
# Out:
# WARNING:datasets.builder:Using custom data configuration default-87b779d0372a9915
# ...
# Extracting data files:   0%|          | 0/1 [00:00<?, ?it/s]
# 0 tables [00:00, ? tables/s]
# Dataset csv downloaded and prepared to /root/.cache/huggingface/datasets/csv/default-87b779d0372a9915/0.0.0/652c3096f041ee27b04d2232d41f10547a8fecda3e284a79a0ec4053c916ef7a. Subsequent calls will reuse this data.
#   0%|          | 0/1 [00:00<?, ?it/s]

# %%
test_data = load_dataset('csv', data_files=r'C:\Users\Jacqueline Li\Desktop\New folder\test_data.csv')
# Out:
# WARNING:datasets.builder:Using custom data configuration default-9b40169191d5f9b7
# ...
# Extracting data files:   0%|          | 0/1 [00:00<?, ?it/s]
# 0 tables [00:00, ? tables/s]
# Dataset csv downloaded and prepared to /root/.cache/huggingface/datasets/csv/default-9b40169191d5f9b7/0.0.0/652c3096f041ee27b04d2232d41f10547a8fecda3e284a79a0ec4053c916ef7a. Subsequent calls will reuse this data.
#   0%|          | 0/1 [00:00<?, ?it/s]

# %%
test_data["train"]
# Out:
# Dataset({
#     features: ['text', 'label'],
#     num_rows: 63978
# })

# %%
from transformers import AutoTokenizer

tokenizer = AutoTokenizer.from_pretrained("distilbert-base-uncased")
# Out:
# loading configuration file config.json from cache at /root/.cache/huggingface/hub/models--distilbert-base-uncased/snapshots/043235d6088ecd3dd5fb5ca3592b6913fd516027/config.json
# Model config DistilBertConfig {
#   "_name_or_path": "distilbert-base-uncased",
#   "activation": "gelu",
#   "architectures": [
#     "DistilBertForMaskedLM"
#   ],
#   "attention_dropout": 0.1,
#   "dim": 768,
#   "dropout": 0.1,
#   "hidden_dim": 3072,
#   "initializer_range": 0.02,
#   "max_position_embeddings": 512,
#   "model_type": "distilbert",
#   "n_heads": 12,
#   "n_layers": 6,
#   "pad_token_id": 0,
#   "qa_dropout": 0.1,
#   "seq_classif_dropout": 0.2,
#   "sinusoidal_pos_embds": false,
#   "tie_weights_": true,
#   "transformers_version": "4.22.0.dev0",
#   "vocab_size": 30522
# }
#
# loading file vocab.txt from cache at /root/.cache/huggingface/hub/models--distilbert-base-uncased/snapshots/043235d6088ecd3dd5fb5ca3592b6913fd516027/vocab.txt
# ...

# %%
def preprocess_function(examples):
  return tokenizer(examples["text"], truncation=True)

# %%
to = data.map(preprocess_function, batched= True)
# Out:
#   0%|          | 0/160 [00:00<?, ?ba/s]

# %%
to1 =test_data.map(preprocess_function, batched=True)
# Out:
#   0%|          | 0/64 [00:00<?, ?ba/s]

# %%
print(to)
print(to1)
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['text', 'label', 'input_ids', 'attention_mask'],
#         num_rows: 159571
#     })
# })
# DatasetDict({
#     train: Dataset({
#         features: ['text', 'label', 'input_ids', 'attention_mask'],
#         num_rows: 63978
#     })
# })

# %%
from transformers import DataCollatorWithPadding
data_collator = DataCollatorWithPadding(tokenizer=tokenizer, return_tensors="tf")

# %%
tf_train_set = to["train"].to_tf_dataset(
    columns=["attention_mask", "input_ids", "label"],
    shuffle=True,
    batch_size=16,
    collate_fn=data_collator,
)

tf_validation_set =to1["train"].to_tf_dataset(
    columns=["attention_mask", "input_ids", "label"],
    shuffle=False,
    batch_size=16,
    collate_fn=data_collator,
)

# %%
from transformers import create_optimizer
import tensorflow as tf

batch_size = 16
num_epochs = 5
batches_per_epoch = len(to["train"]) // batch_size
total_train_steps = int(batches_per_epoch * num_epochs)
optimizer, schedule = create_optimizer(init_lr=2e-5, num_warmup_steps=0, num_train_steps=total_train_steps)

# %%
from transformers import TFAutoModelForSequenceClassification

model = TFAutoModelForSequenceClassification.from_pretrained("distilbert-base-uncased", num_labels=2)
# Out:
# loading configuration file config.json from cache at /root/.cache/huggingface/hub/models--distilbert-base-uncased/snapshots/043235d6088ecd3dd5fb5ca3592b6913fd516027/config.json
# Model config DistilBertConfig {
#   "_name_or_path": "distilbert-base-uncased",
#   "activation": "gelu",
#   "architectures": [
#     "DistilBertForMaskedLM"
#   ],
#   "attention_dropout": 0.1,
#   "dim": 768,
#   "dropout": 0.1,
#   "hidden_dim": 3072,
#   "initializer_range": 0.02,
#   "max_position_embeddings": 512,
#   "model_type": "distilbert",
#   "n_heads": 12,
#   "n_layers": 6,
#   "pad_token_id": 0,
#   "qa_dropout": 0.1,
#   "seq_classif_dropout": 0.2,
#   "sinusoidal_pos_embds": false,
#   "tie_weights_": true,
#   "transformers_version": "4.22.0.dev0",
#   "vocab_size": 30522
# }
#
# loading weights file tf_model.h5 from cache at /root/.cache/huggingface/hub/models--distilbert-base-uncased/snapshots/043235d6088ecd3dd5fb5ca3592b6913fd516027/tf_model.h5
# ...

# %%
import tensorflow as tf

model.compile(loss='sparse_categorical_crossentropy', optimizer='adam')

# %%
tf_train_set
# Out:
# <PrefetchDataset element_spec={'input_ids': TensorSpec(shape=(None, None), dtype=tf.int64, name=None), 'attention_mask': TensorSpec(shape=(None, None), dtype=tf.int64, name=None), 'labels': TensorSpec(shape=(None,), dtype=tf.int64, name=None)}>

# %%
model.fit(x=tf_train_set, validation_data=tf_validation_set, epochs=3)
# Out:
# Epoch 1/3
#  394/9974 [>.............................] - ETA: 84:48:10 - loss: 0.7837
